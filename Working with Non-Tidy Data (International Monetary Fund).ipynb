# %%
import pandas as pd
import numpy as np
from pathlib import Path

# %%
home_path = Path.home() / "Downloads"

# %%
data = pd.read_csv(home_path / "Data.csv")

# %%
data.drop(columns=['Country/Series-specific Notes', 'Estimates Start After'], inplace=True)

# %%
data.head()
# Out:
#        Country                       Subject Descriptor  \
# 0  Afghanistan  Gross domestic product, constant prices
# 1  Afghanistan       Inflation, average consumer prices
# 2  Afghanistan                        Unemployment rate
# 3      Albania  Gross domestic product, constant prices
# 4      Albania       Inflation, average consumer prices
#
#                           Units     Scale     2017     2018     2019     2020  \
# 0             National currency  Billions  506.215  517.858  533.394  552.063
# 1                         Index       NaN  110.998  111.693  113.815  117.799
# 2  Percent of total labor force       NaN      NaN      NaN      NaN      NaN
# 3             National currency  Billions  789.653  822.522   852.66  885.573
# 4                         Index       NaN  103.295   105.39  107.498  110.077
#
#       2021     2022     2023      2024
# 0  574.127  599.933   629.88   664.452
# 1  123.099  129.254  135.717   142.503
# 2      NaN      NaN      NaN       NaN
# 3  919.717  956.167  994.155  1,033.83
# 4   113.16  116.554  120.051   123.653

# %%
#Ensuring the values are the same for all columns to get rid of them
print(f"\n{data['Scale'].value_counts()}")

print(f"\n{data['Units'].value_counts()}")
# Out:
# Billions    194
# Name: Scale, dtype: int64
#
# Index                           194
# Percent of total labor force    194
# National currency               194
# Name: Units, dtype: int64

# %%
#id_vars are the variables we don't want to melt
#Unless explicitly stated, all the other variables in the dataframe will be melted,
# so they should all be of the same "type" (normally columns by year)
#Var_name provides the name of the newly formed column
#Value_name provides the name of the second column with the actual values
melted_data = pd.melt(data, id_vars=['Country', 'Subject Descriptor', 'Units', 'Scale'],
                       var_name="Year", value_name="Value")

# %%
melted_data.head()
# Out:
#        Country                       Subject Descriptor  \
# 0  Afghanistan  Gross domestic product, constant prices
# 1  Afghanistan       Inflation, average consumer prices
# 2  Afghanistan                        Unemployment rate
# 3      Albania  Gross domestic product, constant prices
# 4      Albania       Inflation, average consumer prices
#
#                           Units     Scale  Year    Value
# 0             National currency  Billions  2017  506.215
# 1                         Index       NaN  2017  110.998
# 2  Percent of total labor force       NaN  2017      NaN
# 3             National currency  Billions  2017  789.653
# 4                         Index       NaN  2017  103.295

# %%
#Now that we've "melted" our year columns into one column, we can now pivot to something else.
#To break out the different measures shown for each country, we use pd.pivot_table
# This is a more generalizable version of pd.pivot, allowing us to use multiple indexes.
# We also set the aggregation function to first since we don't want mean values in the case of multiple
# values but simply to use the 'first' value found.
df = pd.DataFrame(pd.pivot_table(melted_data, index=['Country','Year'], columns='Subject Descriptor',
              values='Value', aggfunc='first'))

# %%
df.reset_index(inplace=True)

# %%
#Adding Back in Units and Scale Columns by simply adding to column names
df.columns = ['Country', 'Year','GDP (constant prices, national currency, Billions)',
              'INFLATION (average consumer prices, Index, NaN)', 
              'UNEMPLOYMENT RATE (percent of total work force, NaN)']

# %%
df.head(30)
# Out:
#         Country  Year GDP (constant prices, national currency, Billions)  \
# 0   Afghanistan  2017                                            506.215
# 1   Afghanistan  2018                                            517.858
# 2   Afghanistan  2019                                            533.394
# 3   Afghanistan  2020                                            552.063
# 4   Afghanistan  2021                                            574.127
# 5   Afghanistan  2022                                            599.933
# 6   Afghanistan  2023                                             629.88
# 7   Afghanistan  2024                                            664.452
# 8       Albania  2017                                            789.653
# 9       Albania  2018                                            822.522
# 10      Albania  2019                                             852.66
# 11      Albania  2020                                            885.573
# 12      Albania  2021                                            919.717
# 13      Albania  2022                                            956.167
# 14      Albania  2023                                            994.155
# 15      Albania  2024                                           1,033.83
# 16      Algeria  2017                                           7,371.95
# 17      Algeria  2018                                           7,523.77
# 18      Algeria  2019                                           7,698.00
# 19      Algeria  2020                                           7,834.77
# 20      Algeria  2021                                           7,942.04
# 21      Algeria  2022                                           8,028.24
# 22      Algeria  2023                                           8,059.26
# 23      Algeria  2024                                           8,094.12
# 24       Angola  2017                                           1,586.58
# 25       Angola  2018                                           1,559.62
# 26       Angola  2019                                           1,566.54
# 27       Angola  2020                                           1,611.68
# 28       Angola  2021                                           1,647.44
# 29       Angola  2022                                           1,696.23
#
#    INFLATION (average consumer prices, Index, NaN)  \
# 0                                          110.998
# 1                                          111.693
# 2                                          113.815
# 3                                          117.799
# 4                                          123.099
# 5                                          129.254
# 6                                          135.717
# 7                                          142.503
# 8                                          103.295
# 9                                           105.39
# 10                                         107.498
# 11                                         110.077
# 12                                          113.16
# 13                                         116.554
# 14                                         120.051
# 15                                         123.653
# 16                                          193.97
# 17                                         202.253
# 18                                         213.579
# 19                                         227.888
# 20                                         247.715
# 21                                         272.982
# 22                                         306.285
# 23                                         349.165
# 24                                         251.795
# 25                                         301.218
# 26                                         353.821
# 27                                         393.158
# 28                                         424.214
# 29                                         451.585
#
#    UNEMPLOYMENT RATE (percent of total work force, NaN)
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                              13.756
# 9                                                12.2
# 10                                             13.719
# 11                                             13.225
# 12                                             13.048
# 13                                             13.331
# 14                                             13.201
# 15                                             13.193
# 16                                             11.709
# 17                                             11.731
# 18                                             12.575
# 19                                             13.677
# 20                                             14.957
# 21                                             16.384
# 22                                              18.12
# 23                                             19.847
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN

# %%
df.to_csv("Clean_Data.csv", index=False)
