# %%
from bs4 import BeautifulSoup, Comment
import requests
import pandas as pd

# %%
broad_url = 'https://installations.militaryonesource.mil/military-installation/nellis-afb'
req = requests.get(broad_url)
soup = BeautifulSoup(req.content, 'html.parser')

# %%
soup
# Out:
# <!DOCTYPE doctype html>
#
# <html data-ng-app="myapp" data-ng-strict-di="" lang="en">
# <head>
# <!-- Handle redirection -->
# <script src="/forwarder.js"></script>
# <!-- Google Tag Manager -->
# <script>
#         var dataLayer = [], sContainerId = '', sGAEnvironmentData = '';
#         // MI
#         if (1 + window.location.hostname.indexOf('installations.pre.militaryonesource.mil')) {
#             sContainerId = 'GTM-W8B9R8W';
#             sGAEnvironmentData = '&gtm_auth=zxJFk0dR9QQMBC5JSPlQkg&gtm_preview=env-6&gtm_cookies_win=x';
#         }
#         if (1 + window.location.hostname.indexOf('installations.militaryonesource.mil')) sContainerId = 'GTM-W8B9R8W';
#
#         // PMD
#         if (1 + window.location.hostname.indexOf('planmydeployment.pre.militaryonesource.mil')) {
#             sContainerId = 'GTM-NCQVFN7';
#             sGAEnvironmentData = '&gtm_auth=XRvU4IGhnYoTz2o8LXD4gA&gtm_preview=env-23&gtm_cookies_win=x';
#         }
# ...

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE doctype html>
# <html data-ng-app="myapp" data-ng-strict-di="" lang="en">
#  <head>
#   <!-- Handle redirection -->
#   <script src="/forwarder.js">
#   </script>
#   <!-- Google Tag Manager -->
#   <script>
#    var dataLayer = [], sContainerId = '', sGAEnvironmentData = '';
#         // MI
#         if (1 + window.location.hostname.indexOf('installations.pre.militaryonesource.mil')) {
#             sContainerId = 'GTM-W8B9R8W';
#             sGAEnvironmentData = '&gtm_auth=zxJFk0dR9QQMBC5JSPlQkg&gtm_preview=env-6&gtm_cookies_win=x';
#         }
#         if (1 + window.location.hostname.indexOf('installations.militaryonesource.mil')) sContainerId = 'GTM-W8B9R8W';
#
#         // PMD
#         if (1 + window.location.hostname.indexOf('planmydeployment.pre.militaryonesource.mil')) {
#             sContainerId = 'GTM-NCQVFN7';
#             sGAEnvironmentData = '&gtm_auth=XRvU4IGhnYoTz2o8LXD4gA&gtm_preview=env-23&gtm_cookies_win=x';
#         }
# ...

# %%
list(soup.children)
# Out:
# ['doctype html',
#  '\n',
#  <html data-ng-app="myapp" data-ng-strict-di="" lang="en">
#  <head>
#  <!-- Handle redirection -->
#  <script src="/forwarder.js"></script>
#  <!-- Google Tag Manager -->
#  <script>
#          var dataLayer = [], sContainerId = '', sGAEnvironmentData = '';
#          // MI
#          if (1 + window.location.hostname.indexOf('installations.pre.militaryonesource.mil')) {
#              sContainerId = 'GTM-W8B9R8W';
#              sGAEnvironmentData = '&gtm_auth=zxJFk0dR9QQMBC5JSPlQkg&gtm_preview=env-6&gtm_cookies_win=x';
#          }
#          if (1 + window.location.hostname.indexOf('installations.militaryonesource.mil')) sContainerId = 'GTM-W8B9R8W';
#
#          // PMD
#          if (1 + window.location.hostname.indexOf('planmydeployment.pre.militaryonesource.mil')) {
#              sContainerId = 'GTM-NCQVFN7';
#              sGAEnvironmentData = '&gtm_auth=XRvU4IGhnYoTz2o8LXD4gA&gtm_preview=env-23&gtm_cookies_win=x';
#          }
# ...

# %%
[type(item) for item in list(soup.children)]
# Out:
# [bs4.element.Doctype, bs4.element.NavigableString, bs4.element.Tag]

# %%
html = list(soup.children)[2]

# %%
html
# Out:
# <html data-ng-app="myapp" data-ng-strict-di="" lang="en">
# <head>
# <!-- Handle redirection -->
# <script src="/forwarder.js"></script>
# <!-- Google Tag Manager -->
# <script>
#         var dataLayer = [], sContainerId = '', sGAEnvironmentData = '';
#         // MI
#         if (1 + window.location.hostname.indexOf('installations.pre.militaryonesource.mil')) {
#             sContainerId = 'GTM-W8B9R8W';
#             sGAEnvironmentData = '&gtm_auth=zxJFk0dR9QQMBC5JSPlQkg&gtm_preview=env-6&gtm_cookies_win=x';
#         }
#         if (1 + window.location.hostname.indexOf('installations.militaryonesource.mil')) sContainerId = 'GTM-W8B9R8W';
#
#         // PMD
#         if (1 + window.location.hostname.indexOf('planmydeployment.pre.militaryonesource.mil')) {
#             sContainerId = 'GTM-NCQVFN7';
#             sGAEnvironmentData = '&gtm_auth=XRvU4IGhnYoTz2o8LXD4gA&gtm_preview=env-23&gtm_cookies_win=x';
#         }
# ...

# %%
[type(item) for item in list(html.children)]
# Out:
# [bs4.element.NavigableString,
#  bs4.element.Tag,
#  bs4.element.NavigableString,
#  bs4.element.Tag,
#  bs4.element.NavigableString]

# %%
body = list(html.children)[3]

# %%
body
# Out:
# <body data-supercloak="">
# <!-- Halfaker Google Analytics -->
# <noscript id="gtm-no-script"></noscript>
# <!--End of Halfaker Google Analytics -->
# <div class="universalnav" id="universalnav-navigation"></div>
# <script>
#         /****** Update with your data layer if you are using a GTM data layer and it is not named dataLayer.  Replace the value within single quotes with the name of your datalayer,  It IS Case Sensitive ******/
#         passedInDataLayer2 = 'dataLayer';
#         (function (e, n, t, a) {
#             var s, i = e.getElementsByTagName(n)[0], r = e.getElementById("universalnav-navigation");
#             r.style.background = "#1f365e", r.style.minHeight = "36px", e.getElementById(t) ||
#                 ((s = e.createElement(n)).id = t,
#                     s.src = "https://download.militaryonesource.mil/MOS/universalnav.min.js",
#                     i.parentNode.insertBefore(s, i))
#         })(document, "script", "universalnav-js");
# ...

# %%
[type(item) for item in list(body.children)]
# Out:
# [bs4.element.NavigableString,
#  bs4.element.Comment,
#  bs4.element.NavigableString,
#  bs4.element.Tag,
#  bs4.element.NavigableString,
#  bs4.element.Comment,
#  bs4.element.NavigableString,
#  bs4.element.Tag,
#  bs4.element.NavigableString,
#  bs4.element.Tag,
#  bs4.element.NavigableString,
#  bs4.element.Tag,
#  bs4.element.NavigableString,
#  bs4.element.Tag,
#  bs4.element.NavigableString,
#  bs4.element.Tag,
#  bs4.element.NavigableString,
#  bs4.element.Tag,
#  bs4.element.NavigableString,
#  bs4.element.Tag,
#  bs4.element.NavigableString,
#  bs4.element.Tag,
#  bs4.element.NavigableString,
#  bs4.element.Tag,
#  bs4.element.NavigableString,
#  bs4.element.Tag,
#  bs4.element.NavigableString,
#  bs4.element.Tag,
#  bs4.element.NavigableString,
#  bs4.element.Tag,
#  bs4.element.NavigableString,
#  bs4.element.Tag,
#  bs4.element.NavigableString,
#  bs4.element.Tag,
#  bs4.element.NavigableString,
#  bs4.element.Tag,
#  bs4.element.NavigableString,
#  bs4.element.Tag,
# ...

# %%
div = list(body.children)[15]

# %%
list(div.children)
# Out:
# ['\n', <div data-autoscroll="" data-ng-view=""></div>, '\n']

# %%
next = list(div.children)[1]

# %%
list(next.children) #Why is this EMPTY????????
# Out:
# []

# %%
test = soup.find('div', {'class':'row'})
test
# Out:
# <div class="row">
# <div class="col-md-3" data-ng-repeat="arrFooterCol in arrFooterLinks">
# <div data-ng-repeat="oNav in arrFooterCol">
# <h3 class="nav-title">{{oNav.sTitle}}</h3>
# <ul class="nav-body nobullets">
# <li data-ng-repeat="oLink in oNav.arrLinks">
# <a aria-describedby="open-new-window" class="link light" data-ng-if="!oLink.bLocal" href="{{ oLink.sRef.indexOf('http') === 0 ? oLink.sRef : _fConvertRelativeToAbsoluteUrl(oLink.sRef) }}" target="_blank">
#                                     {{oLink.sName}}</a>
# <a class="link light" data-ng-if="oLink.bLocal" href="{{ oLink.sRef.indexOf('http') === 0 ? oLink.sRef : _fConvertRelativeToAbsoluteUrl(oLink.sRef) }}">
#                                     {{oLink.sName}}</a>
# </li>
# </ul>
# </div>
# </div>
# </div>

# %%
test1 =list(test.children)[1]

# %%
[type(item) for item in list(test1)]
# Out:
# [bs4.element.NavigableString, bs4.element.Tag, bs4.element.NavigableString]

# %%
list(test1.children)
# Out:
# ['\n', <div data-ng-repeat="oNav in arrFooterCol">
#  <h3 class="nav-title">{{oNav.sTitle}}</h3>
#  <ul class="nav-body nobullets">
#  <li data-ng-repeat="oLink in oNav.arrLinks">
#  <a aria-describedby="open-new-window" class="link light" data-ng-if="!oLink.bLocal" href="{{ oLink.sRef.indexOf('http') === 0 ? oLink.sRef : _fConvertRelativeToAbsoluteUrl(oLink.sRef) }}" target="_blank">
#                                      {{oLink.sName}}</a>
#  <a class="link light" data-ng-if="oLink.bLocal" href="{{ oLink.sRef.indexOf('http') === 0 ? oLink.sRef : _fConvertRelativeToAbsoluteUrl(oLink.sRef) }}">
#                                      {{oLink.sName}}</a>
#  </li>
#  </ul>
#  </div>, '\n']

# %%
soup.find_all('div', class_='page')
# Out:
# [<div class="page" role="main">
#  <div data-autoscroll="" data-ng-view=""></div>
#  </div>]

# %%
# from requests_html import HTMLSession

# import asyncio
# if asyncio.get_event_loop().is_running(): # Only patch if needed (i.e. running in Notebook, Spyder, etc)
#     import nest_asyncio
#     nest_asyncio.apply()

# session = HTMLSession()
# r = session.get(broad_url)
# r.html.render()
